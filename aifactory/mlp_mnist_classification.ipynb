# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 숫자 손글씨 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 7

# %% [markdown]
# 그럼 모델 학습에 사용할 훈련셋의 이미지와 라벨을 확인해보겠습니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(10, 13), 
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    ax.set_title(y_train[i])

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 2차원(샘플수, 벡터수)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
y_train[0:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 1차원의 784개 벡터
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy

# %%
model = Sequential([
    Dense(64, input_dim=28*28, activation='relu'), 
    Dense(32, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 준비된 훈련셋으로 모델을 학습시킵니다. fit()는 매 에포크에 해당하는 손실값과 평가 메트릭 수치를 반환합니다.

# %%
hist = model.fit(x_train, y_train, batch_size=32, epochs=100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.3075 - accuracy: 0.9118
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1324 - accuracy: 0.9610
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0963 - accuracy: 0.9710
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0764 - accuracy: 0.9765
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0634 - accuracy: 0.9803
# Epoch 6/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0536 - accuracy: 0.9829
# Epoch 7/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0447 - accuracy: 0.9856
# Epoch 8/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0398 - accuracy: 0.9869
# Epoch 9/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0339 - accuracy: 0.9890
# Epoch 10/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0304 - accuracy: 0.9899
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0268 - accuracy: 0.9909
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0236 - accuracy: 0.9922
# Epoch 13/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0219 - accuracy: 0.9921
# Epoch 14/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0191 - accuracy: 0.9935
# Epoch 15/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0178 - accuracy: 0.9938
# Epoch 16/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0168 - accuracy: 0.9941
# Epoch 17/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0137 - accuracy: 0.9956
# Epoch 18/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0161 - accuracy: 0.9945
# Epoch 19/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0127 - accuracy: 0.9958
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0141 - accuracy: 0.9952
# Epoch 21/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0126 - accuracy: 0.9957
# Epoch 22/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0135 - accuracy: 0.9952
# Epoch 23/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0105 - accuracy: 0.9964
# Epoch 24/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0122 - accuracy: 0.9959
# Epoch 25/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0094 - accuracy: 0.9967
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0103 - accuracy: 0.9965
# Epoch 27/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 28/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0093 - accuracy: 0.9968
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0076 - accuracy: 0.9970
# Epoch 31/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0087 - accuracy: 0.9972
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0105 - accuracy: 0.9963
# Epoch 33/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0070 - accuracy: 0.9974
# Epoch 34/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 35/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0079 - accuracy: 0.9974
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0094 - accuracy: 0.9968
# Epoch 37/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 38/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9977
# Epoch 39/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0078 - accuracy: 0.9976
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0069 - accuracy: 0.9977
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0073 - accuracy: 0.9977
# Epoch 43/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 44/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 45/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 46/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 0.9980
# Epoch 47/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 48/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0069 - accuracy: 0.9979
# Epoch 49/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0061 - accuracy: 0.9982
# Epoch 50/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 51/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 52/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0080 - accuracy: 0.9977
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 54/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9982
# Epoch 55/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 0.9981
# Epoch 56/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 57/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0072 - accuracy: 0.9979
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 60/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9983
# Epoch 61/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 62/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 63/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9979
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0060 - accuracy: 0.9981
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 66/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 67/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9984
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 69/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0072 - accuracy: 0.9979
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 71/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0057 - accuracy: 0.9983
# Epoch 74/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 75/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 76/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9984
# Epoch 77/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9982
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 80/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 82/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0068 - accuracy: 0.9981
# Epoch 83/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 84/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0068 - accuracy: 0.9980
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 86/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 0.9980
# Epoch 87/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 89/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 90/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 91/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 92/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 95/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 97/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9984
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 99/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 100/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋의 손실값과 평가 메트릭 수치를 시각화 하여 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 에포크를 반복할수록 훈련셋의 손실값은 계속 낮아지는 것을 확인할 수 있습니다. 최종 학습된 모델로 평가를 수행합니다.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3006 - accuracy: 0.9770
# Test accuracy 0.9769999980926514
# Test loss 0.30060747265815735

# %% [markdown]
# 또한 시험셋으로 테스트한 결과를 제출하기 위해 모델 결과 파일을 저장합니다. 출력이 10개 클래스에 해당하는 벡터이므로, 분류한 클래스 정보를 얻기 위해 가장 높은 값을 가진 인덱스 값을 가지고 옵니다. 이 인덱스가 클래스를 의미하며, 이 값을 파일로 저장합니다.

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
np.savetxt('y_pred.csv', y_pred, fmt='%d')

# %% [markdown]
# 훈련셋에만 적합된 모델 즉 오버피팅된 모델인지는 확인할 수가 없습니다. 다음 실습에서는 검증셋을 통해서 오버피팅을 모니터링하고, 오버피팅이 되기 전의 모델을 확보하는 방법에 대해서 알아보겠습니다.
